# %%
if 5 > 6 :
    print ('its true')
else:
    print ('false')
# Out:
# false

# %%
sam = False

if sam:
    print("He is Chosen")
else:
    print("Work hard and follow Jesus")
# Out:
# Work hard and follow Jesus

# %%
import random

loc = ['bank','auto shop','store','airport']
l = random.choice(loc)
print(f"Hey I want to know where is this location {l}")
if l == 'bank':
    print("I knew it, their Money looks cool")

elif l == 'auto shop':
    print("I knew it, their Cars looks cool")

elif l == 'store':
    print("I knew it, Welcome to the store")

else:
    print("Sorry i dont know")
# Out:
# Hey I want to know where is this location bank
# I knew it, their Money looks cool
