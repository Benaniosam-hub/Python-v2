# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is second line
# this is third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')
myfile.read()
# Out:
# 'Hello this is a text file\nthis is second line\nthis is third line\n'

# %%
# %%writefile secondfile.txt
# I created a secondfile for reference
# This will lead to many outrages no I'm kidding
# We all good by the way.
# Out:
# Writing secondfile.txt

# %%
new = open('secondfile.txt')
new.read()
# Out:
# "I created a secondfile for reference\nThis will lead to many outrages no I'm kidding\nWe all good by the way.\n"

# %%
new.read()
# Out:
# ''

# %%
new.seek(0)
# Out:
# 0

# %%
new.read()
# Out:
# "I created a secondfile for reference\nThis will lead to many outrages no I'm kidding\nWe all good by the way.\n"

# %%
new.seek(0)
# Out:
# 0

# %%
new.readlines()
# Out:
# ['I created a secondfile for reference\n',
#  "This will lead to many outrages no I'm kidding\n",
#  'We all good by the way.\n']

# %%
new.readlines()
# Out:
# []

# %%
new.seek(0)
# Out:
# 0

# %%
new.readline()
# Out:
# 'I created a secondfile for reference\n'

# %%
new.readlines()
# Out:
# ["This will lead to many outrages no I'm kidding\n",
#  'We all good by the way.\n']

# %%
new.seek(0)
# Out:
# 0

# %%
new.readlines()
# Out:
# ['I created a secondfile for reference\n',
#  "This will lead to many outrages no I'm kidding\n",
#  'We all good by the way.\n']

# %%
new.close()

# %%
with open("secondfile.txt") as new:
    content = new.readlines()

# %%
content
# Out:
# ['I created a secondfile for reference\n',
#  "This will lead to many outrages no I'm kidding\n",
#  'We all good by the way.\n']

# %%
with open("secondfile.txt",'+r') as filenew:
    review = filenew.read()

# %%
review
# Out:
# "I created a secondfile for reference\nThis will lead to many outrages no I'm kidding\nWe all good by the way.\n"

# %%
# %%writefile myarchive.txt
# This is my first line by the way
# This is my second line by the way and
# This is the third line i ever gonna write
# Out:
# Writing myarchive.txt

# %%
with open("myarchive.txt","r") as f:
    print(f.read())
# Out:
# This is my first line by the way
# This is my second line by the way and
# This is the third line i ever gonna write

# %%
with open("myarchive.txt","a")as f:
    f.write('Ops i added another line too')

# %%
with open("myarchive.txt","r") as f:
    print(f.read())
# Out:
# This is my first line by the way
# This is my second line by the way and
# This is the third line i ever gonna write
# Ops i added another line too

# %%
with open("newfiler.txt","w") as v:
    v.write("New file that I created its excellent to be honest")

# %%
with open("newfiler.txt","r") as v:
    print(v.read())
# Out:
# New file that I created its excellent to be honest
