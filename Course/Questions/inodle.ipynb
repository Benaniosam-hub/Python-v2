# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = a + a

# %%
a = 1.4

# %%
type(a)
# Out:
# float

# %%
my_money = 100

my_tax = 15.5

my_income = my_money - my_tax

# %%
my_income
# Out:
# 84.5

# %%
x = y = [1,2]
x.append(3)
print(y)
# [1,2,3]
# Out:
# [1, 2, 3]

# %%
a,b = 1,2,3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a,b = 1,2,3
#
# ValueError: too many values to unpack (expected 2)

# %%
str1 ="Hello"
str2 = str1
str1 = "World"
print(str2)
# Out:
# Hello

# %%
e,g,*h =[21,32,43,54,65,76,87,90]

# %%
print(e)
# Out:
# 21

# %%
num = 50

def calculate():
    num = 100
    print(num, end =" ")
calculate()
print(num)
# Out:
# 100 50

# %%
print("hello there \nFine lets catch up later!")
# Out:
# hello there
# Fine lets catch up later!

# %%
len("hello im prince")
# Out:
# 15

# %%
len("songs I made is pretty than i thought!")

# %%
mystring = "abcdefghijk"

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[2:9]
# Out:
# 'cdefghi'

# %%
mystring[:15]
# Out:
# 'abcdefghijk'

# %%
new = mystring[:]

print(mystring is new)
# Out:
# True

# %%
text = "hello"
tex = text[:]
print(tex)
# Out:
# hello

# %%
name = "sam"

print("p"+name[1:])
# Out:
# pam

# %%
h = "Hello there"

h = h + " Nice to meet you uncle"
print(h)
# Out:
# Hello there Nice to meet you uncle

# %%
letter = "Real"
letter * 10
# Out:
# 'RealRealRealRealRealRealRealRealRealReal'

# %%
i = "Hello World"

# %%
i.upper()
# Out:
# 'HELLO WORLD'

# %%
i.lower()
# Out:
# 'hello world'

# %%
i.capitalize()
# Out:
# 'Hello world'

# %%
x = "Hello rosy we gonna tour"

x.split("o")
# Out:
# ['Hell', ' r', 'sy we g', 'nna t', 'ur']

# %%
print ('This how its done {}'.format("Individuals"))
# Out:
# This how its done Individuals

# %%
print ("Here is the magic {b} {a} {m}".format(a="apple",m="mango",b="banana"))
# Out:
# Here is the magic banana apple mango

# %%
print ("Here is the magic {} {} {}".format("apple","mango","banana"))
# Out:
# Here is the magic apple mango banana

# %%
print ("Here is the magic {2} {1} {0}".format("apple","mango","banana"))
# Out:
# Here is the magic banana mango apple

# %%
result = 100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print ("The final result is {r:1.5f}".format(r=result))
# Out:
# The final result is 0.12870

# %%
print(f"This is the final result: {result:1.4f}")
# Out:
# This is the final result: 0.1287
